# %%
## Import Necessary Libraries
import pprint
from fastcore.basics import patch
import networkx as nx
import ipywidgets as widgets
import ipycytoscape
from ipycytoscape import CytoscapeWidget
from IPython.display import display, HTML
import pandas as pd
from ipydatagrid import DataGrid
from json import load
import pandas as pd

## Creating Author Class
class Author:
    def __init__(self, first, middle, last, email=None, publications=[]):
        self.first = first
        self.middle = middle
        self.last = last
        self.email = email
        self.publications = publications

## Make format pretty
@patch
def __repr__(self:Author):
    return pprint.pformat(vars(self))

## Mock Dataset
a1 = Author('A', 'B', 'Carlson', publications=[1, 2, 3])
a2 = Author('B', 'C', 'Dawson', publications=[3, 4, 5, 6])
a3 = Author('C', 'D', 'Elfson', publications=[1, 5, 7, 8])
a4 = Author('D', 'E', 'Fitzgerald', publications=[1, 5, 9, 10])
a5 = Author('E', 'F', 'Gerard', publications=[4, 11, 12])
a5

authors = [a1, a2, a3, a4, a5]

#### Step 1: Making sure correct matches are found between authors ####

# Create the graph
G = nx.Graph()

for index_a in range(len(authors)):
    for index_b in range(index_a + 1, len(authors)):
        author_a = authors[index_a]
        author_b = authors[index_b]

        common_publications = set(author_a.publications).intersection(author_b.publications)
        if common_publications:
            # Add the weighted edge to the graph
            G.add_edge(author_a, author_b, weight=len(common_publications))

# Add nodes to the graph
for author in authors:
    G.add_node(author, tooltip=author.__repr__())

#### Step 2: Adding titles ####

# Create a label for the title
title_label = widgets.Label(value='Author Network Graph', style={'font-weight': 'bold'})

# Create the Cytoscape widget
cyto = CytoscapeWidget()
cyto.graph.add_graph_from_networkx(G)

# Custom CSS style to change tooltip's background color
custom_style = """
.tippy-tooltip {
    background-color: white
}
"""
# Display the custom CSS style
display(HTML(f"<style>{custom_style}</style>"))

# Create an output widget for displaying author data in the grid
author_data_grid = widgets.Output()

# Callback function for handling node click event
def on_node_click(event):
    with author_data_grid:
        author_data_grid.clear_output()
        if 'node' in event['data']:
            # Get the author name from the clicked node
            author_name = event['data']['node']['tooltip']
            # Find the corresponding Author object
            author = next((a for a in authors if str(a.__repr__()) == author_name), None)
            if author:
                # Create widgets for author information
                first_name_label = widgets.Label(f"First Name: {author.first}")
                middle_name_label = widgets.Label(f"Middle Name: {author.middle}")
                last_name_label = widgets.Label(f"Last Name: {author.last}")
                email_label = widgets.Label(f"Email: {author.email or 'N/A'}")
                publications_label = widgets.Label(f"Publications: {str(author.publications)}")
                # Display the author information in the grid
                display(widgets.VBox([first_name_label, middle_name_label, last_name_label, email_label, publications_label]))

# Set the callback function for node click event
cyto.on('node', 'click', on_node_click)

# Create the grid layout with author_data_grid on the left side and cyto widget on the right side
grid = widgets.GridBox([author_data_grid, cyto], layout=widgets.Layout(grid_template_columns="50% 50%"))

# Set the column widths to ensure proper layout
grid.children[0].layout.width = "100%"

# Display the widgets using a VBox layout
widgets.VBox([title_label, grid])
# Out:
# <style>
# .tippy-tooltip {
#     background-color: white
# }
# </style>
# VBox(children=(Label(value='Author Network Graph'), GridBox(children=(Output(layout=Layout(width='100%')), Cyt…

# %%
## Import Necessary Libraries
import pprint
from fastcore.basics import patch
import networkx as nx
import ipywidgets as widgets
import ipycytoscape
from ipycytoscape import CytoscapeWidget
from IPython.display import display, HTML
import pandas as pd
from ipydatagrid import DataGrid
from json import load
import pandas as pd

## Creating Author Class
class Author:
    def __init__(self, first, middle, last, email=None, publications=[]):
        self.first = first
        self.middle = middle
        self.last = last
        self.email = email
        self.publications = publications

## Make format pretty
@patch
def __repr__(self:Author):
    return pprint.pformat(vars(self))

## Mock Dataset
a1 = Author('A', 'B', 'Carlson', publications = [1,2,3])
a2 = Author('B', 'C', 'Dawson', publications = [3, 4, 5 ,6])
a3 = Author('C', 'D', 'Elfson', publications = [1, 5, 7, 8])
a4 = Author('D', 'E', 'Fitzgerald', publications = [1, 5, 9, 10])
a5 = Author('E', 'F', 'Gerard', publications = [4, 11, 12])
a5

authors = [a1, a2, a3, a4, a5]

#### Step 1: Making sure correct matches are found between authors ####

# Create the graph
G = nx.Graph()

for index_a in range(len(authors)):
    for index_b in range(index_a + 1, len(authors)):
        author_a = authors[index_a]
        author_b = authors[index_b]

        for publication_a in author_a.publications:
            for publication_b in author_b.publications:
                if publication_a == publication_b:
                    G.add_edge(author_a, author_b)

# Add nodes to the graph
for author in authors:
     G.add_node(author, tooltip=author.__repr__())


with authors as fobj:
    data = load(fobj)
df = pd.DataFrame(data["data"]).drop("index", axis = 1)

datagrid = DataGrid(authors, editable=False, layout={"height": "200 px"})
datagrid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 53
#      49             G.add_edge(author_a, author_b, weight=len(common_publications))
#      52 # Create the datagrid widget
# ---> 53 datagrid = DataGrid(authors, editable=False, layout={"height": "200px"})
#      55 # Function to update datagrid with authors list information
#      56 def show_authors_list(btn):
#      57     # Create a DataFrame from the authors list
#
# File ~/anaconda3/envs/web-app/lib/python3.11/site-packages/ipydatagrid/datagrid.py:376, in DataGrid.__init__(self, dataframe, index_name, **kwargs)
#     372 def __init__(self, dataframe, index_name=None, **kwargs):
#     373     # Setting default index name if not explicitly
#     374     # set by the user.
#     375     self._index_name = index_name
# --> 376     self.data = dataframe
#     377     super().__init__(**kwargs)
#     378     self._cell_click_handlers = CallbackDispatcher()
#
# File ~/anaconda3/envs/web-app/lib/python3.11/site-packages/ipydatagrid/datagrid.py:487, in DataGrid.data(self, dataframe)
#     483 @data.setter
#     484 def data(self, dataframe):
#     485     # Reference for the original frame column and index names
#     486     # This is used to when returning the view data model
# --> 487     self.__dataframe_reference_index_names = dataframe.index.names
#     488     self.__dataframe_reference_columns = dataframe.columns
#     489     dataframe = dataframe.copy()
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'names'

# %%
## Import Necessary Libraries
import pprint
from fastcore.basics import patch
import networkx as nx
import ipywidgets as widgets
import ipycytoscape
from ipycytoscape import CytoscapeWidget
from IPython.display import display, HTML
import pandas as pd
from ipydatagrid import DataGrid

## Creating Author Class
class Author:
    def __init__(self, first, middle, last, email=None, publications=[]):
        self.first = first
        self.middle = middle
        self.last = last
        self.email = email
        self.publications = publications

## Make format pretty
@patch
def __repr__(self:Author):
    return pprint.pformat(vars(self))

## Mock Dataset
a1 = Author('A', 'B', 'Carlson', publications=[1, 2, 3])
a2 = Author('B', 'C', 'Dawson', publications=[3, 4, 5, 6])
a3 = Author('C', 'D', 'Elfson', publications=[1, 5, 7, 8])
a4 = Author('D', 'E', 'Fitzgerald', publications=[1, 5, 9, 10])
a5 = Author('E', 'F', 'Gerard', publications=[4, 11, 12])

authors = [a1, a2, a3, a4, a5]

#### Step 1: Making sure correct matches are found between authors ####

# Create the graph
G = nx.Graph()

for index_a in range(len(authors)):
    for index_b in range(index_a + 1, len(authors)):
        author_a = authors[index_a]
        author_b = authors[index_b]

        for publication_a in author_a.publications:
            for publication_b in author_b.publications:
                if publication_a == publication_b:
                    G.add_edge(author_a, author_b)

# Add nodes to the graph
for author in authors:
    G.add_node(author)

# Create the Cytoscape widget to display the network graph
cyto_widget = CytoscapeWidget()
cyto_widget.graph.add_graph_from_networkx(G)

# Function to display the authors' list information
def show_authors_list(btn):
    # Create a DataFrame from the authors' list
    authors_df = pd.DataFrame([vars(author) for author in authors])
    # Display the authors' list in the datagrid
    datagrid = DataGrid(authors_df, editable=False, layout={"height": "200px"})
    output.clear_output()
    with output:
        display(datagrid)

# Create the button widget
button = widgets.Button(description="Show Authors List")
button.on_click(show_authors_list)

# Create an output widget for displaying the datagrid and the network graph
output = widgets.Output()

# Display the widgets using a VBox layout
widgets.VBox([button, cyto_widget, output])
# Out:
# VBox(children=(Button(description='Show Authors List', style=ButtonStyle()), CytoscapeWidget(cytoscape_layout=…
